# %%
print("Hello World")

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.linspace(0, 3 * np.pi, 500)
y = np.sin( np.sin( x**2 ))
plt.plot(x,y)
plt.show()

# %% [markdown]
# $ x = y + a $
# Deskripsi
